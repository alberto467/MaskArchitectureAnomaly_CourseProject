# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from helpers.class_remap import CITY_FROM_COCO, coco_classes, city_classes

# %%
city_classes
# Out:
# [(0, 'road'),
#  (1, 'sidewalk'),
#  (2, 'building'),
#  (3, 'wall'),
#  (4, 'fence'),
#  (5, 'pole'),
#  (6, 'traffic light'),
#  (7, 'traffic sign'),
#  (8, 'vegetation'),
#  (9, 'terrain'),
#  (10, 'sky'),
#  (11, 'person'),
#  (12, 'rider'),
#  (13, 'car'),
#  (14, 'truck'),
#  (15, 'bus'),
#  (16, 'train'),
#  (17, 'motorcycle'),
#  (18, 'bicycle')]

# %%
aset = set([label for labels_list in CITY_FROM_COCO.values() for label in labels_list])
aset
# Out:
# {'bicycle',
#  'building-other-merged',
#  'bus',
#  'car',
#  'dirt-merged',
#  'fence-merged',
#  'flower',
#  'grass-merged',
#  'gravel',
#  'house',
#  'motorcycle',
#  'pavement-merged',
#  'person',
#  'platform',
#  'playingfield',
#  'road',
#  'roof',
#  'sand',
#  'sky-other-merged',
#  'snow',
#  'stop sign',
#  'traffic light',
#  'train',
#  'tree-merged',
#  'truck',
#  'wall-brick',
#  'wall-other-merged',
#  'wall-stone',
#  'wall-tile',
#  'wall-wood'}

# %%
bset = set([name for _, name in coco_classes])
bset
# Out:
# {'airplane',
#  'apple',
#  'backpack',
#  'banana',
#  'banner',
#  'baseball bat',
#  'baseball glove',
#  'bear',
#  'bed',
#  'bench',
#  'bicycle',
#  'bird',
#  'blanket',
#  'boat',
#  'book',
#  'bottle',
#  'bowl',
#  'bridge',
#  'broccoli',
#  'building-other-merged',
#  'bus',
#  'cabinet-merged',
#  'cake',
#  'car',
#  'cardboard',
#  'carrot',
#  'cat',
#  'ceiling-merged',
#  'cell phone',
#  'chair',
#  'clock',
#  'couch',
#  'counter',
#  'cow',
#  'cup',
#  'curtain',
#  'dining table',
#  'dirt-merged',
#  'dog',
#  'donut',
#  'door-stuff',
#  'elephant',
#  'fence-merged',
#  'fire hydrant',
#  'floor-other-merged',
#  'floor-wood',
#  'flower',
#  'food-other-merged',
#  'fork',
#  'frisbee',
#  'fruit',
#  'giraffe',
#  'grass-merged',
#  'gravel',
#  'hair drier',
#  'handbag',
#  'horse',
#  'hot dog',
#  'house',
#  'keyboard',
#  'kite',
#  'knife',
#  'laptop',
#  'light',
#  'microwave',
#  'mirror-stuff',
#  'motorcycle',
#  'mountain-merged',
# ...

# %%
aset - bset
# Out:
# set()

# %%
len(city_classes)
# Out:
# 19
